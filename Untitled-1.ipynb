# %%
public class carro 


//atributos
 String nome;
 String marca;
 int ano;
 int vel;

//métodos
void acelerar(int aceleracao){
    vel += aceleracao;

}

void freiar(int reduzir) {

    vel -= reduzir;

}
void buzinar(){
    print void   ("bibibi")
}
# Out:
#   Cell In[1], line 1
#     public class carro
#            ^
# SyntaxError: invalid syntax
